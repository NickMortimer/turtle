# %%
import glob
import os
import numpy as np
files =glob.glob('T:\*\*.jpg',recursive=True)
files
# Out:
# ['T:\\survey_09\\neds_20180120T090046_1955.jpg',
#  'T:\\survey_09\\neds_20180120T085741_1885.jpg',
#  'T:\\survey_09\\neds_20180120T085843_1908.jpg',
#  'T:\\survey_09\\neds_20180120T090802_2123.jpg',
#  'T:\\survey_09\\neds_20180120T090358_2028.jpg',
#  'T:\\survey_09\\neds_20180120T085656_1867.jpg',
#  'T:\\survey_09\\neds_20180120T085706_1871.jpg',
#  'T:\\survey_09\\neds_20180120T085909_1917.jpg',
#  'T:\\survey_09\\neds_20180120T090858_2144.jpg',
#  'T:\\survey_09\\neds_20180120T090252_2003.jpg',
#  'T:\\survey_09\\neds_20180120T090455_2050.jpg',
#  'T:\\survey_09\\neds_20180120T085753_1889.jpg',
#  'T:\\survey_09\\neds_20180120T085723_1878.jpg',
#  'T:\\survey_09\\neds_20180120T085659_1868.jpg',
#  'T:\\survey_09\\neds_20180120T090518_2059.jpg',
#  'T:\\survey_09\\neds_20180120T090920_2153.jpg',
#  'T:\\survey_09\\neds_20180120T085801_1892.jpg',
#  'T:\\survey_09\\neds_20180120T085946_1932.jpg',
#  'T:\\survey_09\\neds_20180120T090943_2161.jpg',
# ...

# %%
split =os.path.split(files[2])
split[0].split('\\')[0]
# Out:
# 'T:'

# %%
#os.path.splitext([1])[0]

# %%
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
data = [['Alex',10],['Bob',12],['Clarke',13]]
df = pd.DataFrame(data,columns=['description','filename'])
print(df)
# Out:
#   description  filename
# 0        Alex        10
# 1         Bob        12
# 2      Clarke        13

# %%
def proces_filename(filename):
    split =os.path.split(filename)
    classification=split[0].split('\\')[0]
    return {'clasification':classification,'path':filename}
proces_filename(files[0])
data = pd.DataFrame([proces_filename(file) for file in files])
data.head(5219)
#data.to_csv('clasifications.csv')
# Out:
#      clasification                                        path
# 0     T:/survey_09  T:/survey_09\neds_20180120T090046_1955.jpg
# 1     T:/survey_09  T:/survey_09\neds_20180120T085741_1885.jpg
# 2     T:/survey_09  T:/survey_09\neds_20180120T085843_1908.jpg
# 3     T:/survey_09  T:/survey_09\neds_20180120T090802_2123.jpg
# 4     T:/survey_09  T:/survey_09\neds_20180120T090358_2028.jpg
# 5     T:/survey_09  T:/survey_09\neds_20180120T085656_1867.jpg
# 6     T:/survey_09  T:/survey_09\neds_20180120T085706_1871.jpg
# 7     T:/survey_09  T:/survey_09\neds_20180120T085909_1917.jpg
# 8     T:/survey_09  T:/survey_09\neds_20180120T090858_2144.jpg
# 9     T:/survey_09  T:/survey_09\neds_20180120T090252_2003.jpg
# 10    T:/survey_09  T:/survey_09\neds_20180120T090455_2050.jpg
# 11    T:/survey_09  T:/survey_09\neds_20180120T085753_1889.jpg
# 12    T:/survey_09  T:/survey_09\neds_20180120T085723_1878.jpg
# 13    T:/survey_09  T:/survey_09\neds_20180120T085659_1868.jpg
# ...

# %%
import glob
files = glob.glob(r"T:\*\*.jpg")
files
# Out:
# ['T:\\survey_09\\neds_20180120T090046_1955.jpg',
#  'T:\\survey_09\\neds_20180120T085741_1885.jpg',
#  'T:\\survey_09\\neds_20180120T085843_1908.jpg',
#  'T:\\survey_09\\neds_20180120T090802_2123.jpg',
#  'T:\\survey_09\\neds_20180120T090358_2028.jpg',
#  'T:\\survey_09\\neds_20180120T085656_1867.jpg',
#  'T:\\survey_09\\neds_20180120T085706_1871.jpg',
#  'T:\\survey_09\\neds_20180120T085909_1917.jpg',
#  'T:\\survey_09\\neds_20180120T090858_2144.jpg',
#  'T:\\survey_09\\neds_20180120T090252_2003.jpg',
#  'T:\\survey_09\\neds_20180120T090455_2050.jpg',
#  'T:\\survey_09\\neds_20180120T085753_1889.jpg',
#  'T:\\survey_09\\neds_20180120T085723_1878.jpg',
#  'T:\\survey_09\\neds_20180120T085659_1868.jpg',
#  'T:\\survey_09\\neds_20180120T090518_2059.jpg',
#  'T:\\survey_09\\neds_20180120T090920_2153.jpg',
#  'T:\\survey_09\\neds_20180120T085801_1892.jpg',
#  'T:\\survey_09\\neds_20180120T085946_1932.jpg',
#  'T:\\survey_09\\neds_20180120T090943_2161.jpg',
# ...
